# %% [markdown]
# # 物体検知について

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 機能面に関して
#
# ### 【値のセット】
# - サンプルデータ(testimg.jpg):画像データ(jpgもしくはpng)
#
# ### 【予測ボタン：押下】
# - 「アップロードした画像(元データ)」と「物体検知した画像」が表示

# %% [markdown]
# <hr>
#
# ## 物体検知で用いたモデル

# %%
# ライブラリーをインポート
from PIL import Image, ImageFilter
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import cv2
from ultralytics import YOLO
# %matplotlib inline

# %%
#画像を読み込み表示
img = cv2.imread('./data/testimg.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 配列を画像に変換(fromarray)
tmp = Image.fromarray(img)
display(tmp)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
model = YOLO('yolov8n.pt')
results = model(img,conf=0.5)
output_img = results[0].plot(labels=True,conf=True)
# 配列を画像に変換(fromarray)
tmp = Image.fromarray(output_img)
display(tmp)
# Out:
# 0: 448x640 4 persons, 1 bowl, 1 dining table, 61.1ms
# Speed: 2.9ms preprocess, 61.1ms inference, 0.8ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=640x427>
