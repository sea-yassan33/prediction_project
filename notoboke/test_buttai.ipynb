# %% [markdown]
# # 物体検知を実装

# %%
##物体検出AIの代表的なモデルであるYOLOのPython SDK
#!pip install ultralytics

# %%
# ライブラリーをインポート
from PIL import Image, ImageFilter
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import cv2
# %matplotlib inline

# %%
#画像を読み込み表示
img = cv2.imread('./data/testimg.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 配列を画像に変換(fromarray)
tmp = Image.fromarray(img)
display(tmp)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %% [markdown]
# ## 物体検知を実施

# %%
# ライブラリーインポート
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
results = model(img,conf=0.5)
# Out:
# 0: 448x640 4 persons, 1 bowl, 1 dining table, 80.8ms
# Speed: 2.0ms preprocess, 80.8ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)

# %%
output_img = results[0].plot(labels=True,conf=True)
# 配列を画像に変換(fromarray)
tmp = Image.fromarray(output_img)
display(tmp)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
print(tmp)
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x1504E5840>

# %%
boxes = results[0].boxes.xyxy
scores = results[0].boxes.conf
categories = results[0].boxes.cls
print(boxes)
print(scores)
print(categories)
# Out:
# tensor([[  6.3507,  80.5117, 212.3609, 423.5422],
#         [340.7118,  75.1363, 467.1628, 232.5362],
#         [415.1443,  93.5434, 588.7582, 422.5004],
#         [197.6699, 139.1290, 385.1273, 294.7271],
#         [222.7001, 278.5394, 265.2697, 311.5643],
#         [176.5261, 237.7824, 489.0724, 421.5511]])
# tensor([0.9130, 0.7851, 0.7067, 0.6529, 0.5906, 0.5894])
# tensor([ 0.,  0.,  0.,  0., 45., 60.])
